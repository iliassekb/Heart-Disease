# %% [markdown]
# Image ECG originale →
# Crop signal →
# Grayscale →
# Otsu Threshold →
# Morph. Opening →
# Dilation →
# Erosion →
# Inversion →
# Final preprocessed image

# %%
#Imports & Directories
import os
import cv2
import numpy as np
from pathlib import Path

# %%
from pathlib import Path

# Base dataset folder
DATASET_DIR = Path("Datasets")  # your Datasets folder

# Input cropped images folder
CROPPED_DIR = DATASET_DIR / "Dataset_cropped"

# Output folder inside Datasets
OUTPUT_DIR = DATASET_DIR / "Processed_Dataset_Background"
OUTPUT_DIR.mkdir(exist_ok=True, parents=True)

print("Input folder:", CROPPED_DIR.resolve())
print("Output folder:", OUTPUT_DIR.resolve())

# %%
def preprocessing_method(image_path):
    
    # Load image in grayscale
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    
    if img is None:
        return None

    # Apply Otsu's thresholding
    _, binary = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # Morphological opening (remove small black dots/noise)
    kernel_open = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
    opened = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel_open)
    
    # Morphological dilation (thicken lines)
    kernel_dilate = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (2, 2))
    dilated = cv2.dilate(opened, kernel_dilate, iterations=1)
    
    # Morphological erosion (enhance clarity)
    kernel_erode = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (2, 2))
    eroded = cv2.erode(dilated, kernel_erode, iterations=1)
    
    # Invert (white lines on black background)
    inverted = cv2.bitwise_not(eroded)
    
    return inverted

# %%
def process_dataset():
    for class_name in os.listdir(CROPPED_DIR):
        class_path = os.path.join(CROPPED_DIR, class_name)
        if not os.path.isdir(class_path):
            continue
        
        output_class_dir = os.path.join(OUTPUT_DIR, class_name)
        os.makedirs(output_class_dir, exist_ok=True)

        print(f"Processing class: {class_name}")

        for filename in os.listdir(class_path):
            if filename.lower().endswith((".png", ".jpg", ".jpeg")):
                
                img_path = os.path.join(class_path, filename)
                
                processed_img = preprocessing_method(img_path)

                if processed_img is not None:
                    save_path = os.path.join(output_class_dir, filename)
                    cv2.imwrite(save_path, processed_img)

    print("Preprocessing complete. Dataset created!")

# %%
#   Run processing
if __name__ == "__main__":
    process_dataset()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 #   Run processing
#       2 if __name__ == "__main__":
# ----> 3     process_dataset()
#
# Cell In[3], line 2, in process_dataset()
#       1 def process_dataset():
# ----> 2     for class_name in os.listdir(CROPPED_DIR):
#       3         class_path = os.path.join(CROPPED_DIR, class_name)
#       4         if not os.path.isdir(class_path):
#
# NameError: name 'CROPPED_DIR' is not defined
